# %% [markdown]
# # Kristina Safonova

# %% [markdown]
# ## What is the impact of population on the house prices and rental market?
#
# I will be looking at how the population is one factor affecting housing market prices and rental prices in those regions influence those markets. I want to find out whether areas with a smaller population or larger population have higher or lower market prices or there is something more going on.
#
# Below is the dataset that is only used to complete this task - I will be looking at more data for the actual analysis.

# %%
# !pip install pandas

# %%
import pandas as pd
file = ("../data/raw/housing-supply-and-rental/alberta_section1_.csv")

# %%
dataset = pd.read_csv(file)
dataset
# Out:
#    Unnamed: 0 Starts, total   Single-detached      Multiple  \
# 0        1990         17227             13809          3418
# 1        1991         12492              9778          2714
# 2        1992         13809             14125          4448
# 3        1993         18151             13040          5111
# 4        1994         17692             12671          5021
# 5        1995         13906             10096          3810
# 6        1996         16665             12949          3716
# 7        1997         23671             18170          5501
# 8        1998         27122             20077          7045
# 9        1999         25447             16688          8759
# 10       2000         26266             16835          9431
# 11       2001         29174             19769          9405
# 12       2002         38754             24520         14234
# 13       2003         36171             21918         14253
# 14       2004         36270             22487         13783
# ...
